# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita15887/Anndata/blob/main/Untitled58.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Upload your zip file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9df5954b-304d-4f6b-adfc-1131669e9d6b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9df5954b-304d-4f6b-adfc-1131669e9d6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Unzip the dataset
import zipfile
import os

zip_file = "archive (3).zip"  # Replace with your filename
with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall("soil_dataset")

# %%
import os

# Check the main dataset directory
print("Main folders inside 'soil_dataset':", os.listdir("soil_dataset"))

# Check if "clay", "sandy", "loamy" folders are present
for folder in os.listdir("soil_dataset"):
    path = os.path.join("soil_dataset", folder)
    print(f"Inside '{folder}':", os.listdir(path)[:3])  # show first 3 files inside each
# Out:
# Main folders inside 'soil_dataset': ['Dataset']
# Inside 'Dataset': ['test', 'Train']

# %%
data_dir = "soil_dataset/Dataset/Train"

# %%
import os

# List folders inside the Train directory
train_path = "soil_dataset/Dataset/Train"
print("Classes inside Train folder:")
print(os.listdir(train_path))
# Out:
# Classes inside Train folder:
# ['Black Soil', 'Red soil', 'Clay soil', 'Alluvial soil']

# %%
soil_labels = {
    'Black Soil': 0,
    'Red soil': 1,
    'Clay soil': 2,
    'Alluvial soil': 3
}

harvest_map = {
    'Black Soil': 1,
    'Red soil': 1,
    'Clay soil': 0,
    'Alluvial soil': 1
}

fertility_tips = {
    'Black Soil': 'Add organic matter to enhance fertility.',
    'Red soil': 'Use compost and green manure to improve fertility.',
    'Clay soil': 'Improve drainage and add organic compost.',
    'Alluvial soil': 'Apply balanced fertilization to sustain fertility.'
}

# %%
data_dir = "soil_dataset/Dataset/Train"

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical

images = []
texture_labels = []
harvest_labels = []

for label in soil_labels:
    folder_path = os.path.join(data_dir, label)
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        img = cv2.imread(img_path)
        if img is None:
            continue  # Skip unreadable images
        img = cv2.resize(img, (128, 128))
        images.append(img)
        texture_labels.append(soil_labels[label])
        harvest_labels.append(harvest_map[label])

images = np.array(images) / 255.0
texture_labels = to_categorical(texture_labels, num_classes=4)
harvest_labels = np.array(harvest_labels)

# %%
from sklearn.model_selection import train_test_split

# Split into training and validation
X_train, X_val, y_train, y_val = train_test_split(images, texture_labels, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Flatten(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(5, activation='softmax')  # 4 soil types
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 57600)          │             0 │
# ...

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-78f196b5e4d0> in <cell line: 0>()
# ----> 1 history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, batch_size=32)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py in categorical_crossentropy(target, output, from_logits, axis)
#     658     for e1, e2 in zip(target.shape, output.shape):
#     659         if e1 is not None and e2 is not None and e1 != e2:
# ...

# %%
model.save("soil_texture_classifier.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import numpy as np
import cv2
from google.colab import files

# Load the trained model
model = load_model("soil_texture_classifier.h5")

# Upload image
uploaded = files.upload()

# Soil classes used during training
soil_labels = {
    'Black Soil': 0,
    'Red soil': 1,
    'Clay soil': 2,
    'Alluvial soil': 3
}

# Mapping for harvesting suitability
harvest_map = {
    'Black Soil': 1,
    'Red soil': 1,
    'Clay soil': 0,
    'Alluvial soil': 1
}

# Fertility tips for each soil type
fertility_tips = {
    'Black Soil': 'Add organic matter to enhance fertility.',
    'Red soil': 'Use compost and green manure to improve fertility.',
    'Clay soil': 'Improve drainage and add organic compost.',
    'Alluvial soil': 'Apply balanced fertilization to sustain fertility.'
}

# Reverse mapping from index to soil label
label_map = {v: k for k, v in soil_labels.items()}

# Set threshold for confidence — predictions below this are rejected
CONFIDENCE_THRESHOLD = 0.5

# Process uploaded images
for img_name in uploaded:
    img = cv2.imread(img_name)
    if img is None:
        print(f"❌ Could not read image: {img_name}")
        continue

    # Resize and normalize the image
    img_resized = cv2.resize(img, (128, 128))
    img_input = np.expand_dims(img_resized / 255.0, axis=0)

    # Predict using model
    pred = model.predict(img_input)
    confidence = np.max(pred)
    predicted_label_index = np.argmax(pred)

    if confidence < CONFIDENCE_THRESHOLD:
        print(f"🚫 Not a valid soil image. (Prediction confidence: {confidence:.2f})")
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.title(f"Invalid Soil Image (Confidence: {confidence:.2f})")
        plt.axis('off')
        plt.show()
    else:
        predicted_label = label_map[predicted_label_index]
        print(f"🌱 Predicted Soil Texture: {predicted_label}")
        print(f"🧪 Harvesting Suitability: {'✅ Suitable for harvesting' if harvest_map[predicted_label] else '❌ Not suitable for harvesting'}")
        print(f"💡 Fertility Tip: {fertility_tips[predicted_label]}")
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.title(f"{predicted_label} (Confidence: {confidence:.2f})")
        plt.axis('off')
        plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#      <input type="file" id="files-e7250722-6617-448a-ad03-bd91b9897dfc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7250722-6617-448a-ad03-bd91b9897dfc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
